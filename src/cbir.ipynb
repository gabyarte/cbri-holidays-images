# %%
import cv2
import glob
from matplotlib import pyplot as plt

# %%
from sift import sift_euclidean
from smart_histogram import smart_histogram_chisqr

# %%
images = [cv2.imread(file) for file in glob.glob('../data/*.jpg')]

# %%
image = cv2.imread('../data/108102.jpg')
# Out:
# [ WARN:0@5571.600] global loadsave.cpp:244 findDecoder imread_('../data/131502.jpg'): can't open/read file: check file path/integrity

# %%
images.sort(key=lambda img: smart_histogram_chisqr(image, img))
smart_histogram_list = images[:6]
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 images.sort(key=lambda img: smart_histogram_chisqr(image, img))
#       2 smart_histogram_list = images[:6]
#
# Cell In[35], line 1, in <lambda>(img)
# ----> 1 images.sort(key=lambda img: smart_histogram_chisqr(image, img))
#       2 smart_histogram_list = images[:6]
#
# File ~/Documents/UPM/Information Retrieval, Extraction and Integration/cbri-holidays-images/src/smart_histogram.py:51, in smart_histogram_chisqr(img1, img2)
#      50 def smart_histogram_chisqr(img1, img2):
# ---> 51     im1 = smart_histogram_descriptor(img1)
#      52     im2 = smart_histogram_descriptor(img2)
#      53     return distance(im1, im2)
#
# File ~/Documents/UPM/Information Retrieval, Extraction and Integration/cbri-holidays-images/src/smart_histogram.py:33, in smart_histogram_descriptor(img)
#      32 def smart_histogram_descriptor(img):
# ---> 33     equalized = equalize(img)
#      34     split = split_image(equalized)
#      35     return list(map(generate_histograms, split))
#
# File ~/Documents/UPM/Information Retrieval, Extraction and Integration/cbri-holidays-images/src/smart_histogram.py:5, in equalize(img)
#       4 def equalize(img):
# ----> 5     hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
#       6     clahe = cv2.createCLAHE()
#       7     hsv_img[..., 2] = clahe.apply(hsv_img[..., 2])
#
# error: OpenCV(4.7.0) /tmp/opencv-20230122-99400-19ne6ip/opencv-4.7.0/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
for image in smart_histogram_list:
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.show()

# %%
images.sort(key=lambda img: sift_euclidean(image, img))
sift_list = images[:10]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 images.sort(key=lambda img: sift_euclidean(image, img))
#       2 sift_list = images[:10]
#
# Cell In[25], line 1, in <lambda>(img)
# ----> 1 images.sort(key=lambda img: sift_euclidean(image, img))
#       2 sift_list = images[:10]
#
# File ~/Documents/UPM/Information Retrieval, Extraction and Integration/cbri-holidays-images/src/sift.py:15, in sift_euclidean(img1, img2)
#      12 kp2, des2 = sift.detectAndCompute(gray2, None)
#      14 bf = cv2.BFMatcher()
# ---> 15 matches = bf.match(des1, des2)
#      16 return sum(c.distance for c in matches)
#
# KeyboardInterrupt:

# %%
for image in sift_list:
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.show()
